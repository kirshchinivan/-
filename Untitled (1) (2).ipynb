# %% [markdown]
# # Загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.calibration import calibration_curve

# %%
data = pd.read_csv('tr_for_students.csv')

data.head()
# Out:
#       issue_d             purpose addr_state sub_grade home_ownership  \
# 0  2012-01-01  debt_consolidation         IL        C3           RENT
# 1  2013-01-01  debt_consolidation         FL        B4       MORTGAGE
# 2  2013-07-01  debt_consolidation         NJ        B5           RENT
# 3  2014-03-01  debt_consolidation         MI        C2       MORTGAGE
# 4  2013-10-01         credit_card         TX        D2       MORTGAGE
#
#                      emp_title  installment    dti  funded_amnt  annual_inc  \
# 0  Chicago Shakespeare Theatre       172.48  16.39         5000     21600.0
# 1               Queen of Pawns       674.94  16.31        20000     95000.0
# 2                 tek services       809.24  14.01        24000     90000.0
# 3            Inventory Control       342.56  14.51        10000     43000.0
# 4             Business Analyst       473.58  22.65        13000     62000.0
#
#    ...  mths_since_recent_inq  delinq_2yrs  chargeoff_within_12_mths  \
# 0  ...                    NaN            0                         0
# 1  ...                    4.0            0                         0
# 2  ...                   19.0            0                         0
# 3  ...                    5.0            1                         1
# 4  ...                    5.0            0                         0
#
#    num_accts_ever_120_pd  num_tl_90g_dpd_24m  acc_open_past_24mths  \
# 0                    NaN                 NaN                   NaN
# 1                    0.0                 0.0                   4.0
# 2                    0.0                 0.0                   5.0
# 3                    4.0                 1.0                   3.0
# 4                    0.0                 0.0                   5.0
#
#    avg_cur_bal  tot_hi_cred_lim  delinq_amnt  def
# 0          NaN              NaN            0    0
# 1      23735.0         153379.0            0    0
# 2       4070.0          50834.0            0    0
# 3       1127.0          32683.0            0    0
# 4       3443.0          59495.0            0    0
#
# [5 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['issue_d', 'purpose', 'addr_state', 'sub_grade', 'home_ownership',
#        'emp_title', 'installment', 'dti', 'funded_amnt', 'annual_inc',
#        'emp_length', 'term', 'inq_last_6mths', 'mths_since_recent_inq',
#        'delinq_2yrs', 'chargeoff_within_12_mths', 'num_accts_ever_120_pd',
#        'num_tl_90g_dpd_24m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'tot_hi_cred_lim', 'delinq_amnt', 'def'],
#       dtype='object')

# %% [markdown]
# # WOE-преобразование

# %%
def WOE(data, feature, target):
    woe_df = pd.DataFrame()
    s1 = data[target].sum()
    s0 = data[target].count() - s1
    woe_df['DistributionGood'] = data.groupby(feature).agg({target: 'sum'}) / s1
    woe_df['DistributionBad'] = (data.groupby(feature).agg({target: 'count'}) - data.groupby(feature).agg({target: 'sum'})) / s0
    woe_df = woe_df[woe_df['DistributionBad'] != 0]
    woe_df = woe_df[woe_df['DistributionGood'] != 0]
    woe_df['WOE'] = np.log(woe_df['DistributionGood'] / woe_df['DistributionBad'])
    woe_df['IV'] = (woe_df['DistributionGood'] - woe_df['DistributionBad']) * woe_df['WOE']
    return woe_df, woe_df['WOE'], woe_df['IV'].sum()

# %% [markdown]
# # Exploratory Data Analysis

# %%
test = pd.DataFrame()
test['def'] = data['def']

# %% [markdown]
# ## issue_d

# %%
data['issue_d'].isna().sum()
# Out:
# 0

# %%
data['issue_d'].unique()
# Out:
# array(['2012-01-01', '2013-01-01', '2013-07-01', '2014-03-01',
#        '2013-10-01', '2011-11-01', '2011-04-01', '2014-05-01',
#        '2014-02-01', '2013-08-01', '2013-04-01', '2012-11-01',
#        '2010-11-01', '2012-03-01', '2012-07-01', '2013-09-01',
#        '2014-04-01', '2013-03-01', '2014-01-01', '2013-05-01',
#        '2012-12-01', '2013-06-01', '2012-04-01', '2013-11-01',
#        '2012-08-01', '2012-05-01', '2013-12-01', '2011-03-01',
#        '2013-02-01', '2010-08-01', '2011-10-01', '2011-07-01',
#        '2011-08-01', '2010-06-01', '2012-10-01', '2012-09-01',
#        '2010-09-01', '2011-01-01', '2010-10-01', '2011-05-01',
#        '2012-06-01', '2011-06-01', '2011-12-01', '2012-02-01',
#        '2010-05-01', '2011-09-01', '2010-07-01', '2010-04-01',
#        '2011-02-01', '2010-12-01'], dtype=object)

# %% [markdown]
# Так как модель строится для предсказаний, год из обучающей выборки стоит убрать, так как в будущем регулярно будут возникать значения года, не встречавшиеся ранее.
#
# Также дата выдачи кредита уже приведена к месяцу, поэтому оставим только номер месяца.

# %%
test['issue_d'] = data['issue_d'].astype('datetime64[ns]').map(lambda x: x.month)

# %%
test['issue_d'].value_counts()
# Out:
# 5     7137
# 4     6705
# 3     5766
# 2     5413
# 1     5367
# 12    5002
# 10    4782
# 11    4735
# 9     4523
# 8     4199
# 7     3917
# 6     3623
# Name: issue_d, dtype: int64

# %% [markdown]
# Применим WOE-преобразование к месяцу выдачи кредита

# %%
res, woe, iv = WOE(test, 'issue_d', 'def')
res
# Out:
#          DistributionGood  DistributionBad       WOE        IV
# issue_d
# 1                0.085843         0.088101 -0.025961  0.000059
# 2                0.090248         0.088159  0.023416  0.000049
# 3                0.090453         0.094987 -0.048913  0.000222
# 4                0.111760         0.109207  0.023108  0.000059
# 5                0.121184         0.115821  0.045267  0.000243
# 6                0.064126         0.058299  0.095260  0.000555
# 7                0.068326         0.063221  0.077657  0.000396
# 8                0.066277         0.069096 -0.041643  0.000117
# 9                0.070068         0.074679 -0.063732  0.000294
# 10               0.076931         0.078413 -0.019087  0.000028
# 11               0.077136         0.077460 -0.004197  0.000001
# 12               0.077648         0.082557 -0.061301  0.000301

# %%
r = res.sort_values(by='issue_d')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %% [markdown]
# Как можно увидеть, никакой монотонности значений WOE в зависимости от месяца не наблюдается

# %%
iv
# Out:
# 0.0023244007298425843

# %% [markdown]
# IV также заметно ниже порогового значения 0.02

# %% [markdown]
# Попробуем сгруппировать по кварталам:

# %%
test['issue_date_quarter'] = test['issue_d'].map(lambda x: (x - 1) // 3 + 1)

res, woe, iv = WOE(test, 'issue_date_quarter', 'def')
res
# Out:
#                     DistributionGood  DistributionBad       WOE        IV
# issue_date_quarter
# 1                           0.266544         0.271247 -0.017492  0.000082
# 2                           0.297070         0.283327  0.047366  0.000651
# 3                           0.204671         0.206995 -0.011291  0.000026
# 4                           0.231715         0.238431 -0.028571  0.000192

# %%
r = res.sort_values(by='issue_date_quarter')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x)
plt.ylabel('WOE');

# %%
iv
# Out:
# 0.0009513454653790662

# %% [markdown]
# Для кварталов IV еще меньше. Никакой монотонности не появилось.

# %% [markdown]
# Выходит, что знание о месяце выдачи кредита ни при каком из вариантов группировки не является сильным признаком. Поэтому мы не будем использовать данный признак для дальнейшей классификации.

# %% [markdown]
# ## purpose

# %%
data['purpose'].isna().sum()
# Out:
# 0

# %%
data['purpose'].value_counts()
# Out:
# debt_consolidation    35587
# credit_card           13722
# home_improvement       3549
# other                  3111
# major_purchase         1378
# small_business          969
# car                     758
# medical                 587
# moving                  400
# wedding                 390
# house                   356
# vacation                306
# renewable_energy         43
# educational              13
# Name: purpose, dtype: int64

# %% [markdown]
# Есть две категории, встречающиеся очень редко: "educational" и "renewable_energy", и отдельная категория "other", включающая в себя редкие категории. Отнесем "educational" и "renewable_energy" к "other".

# %%
test['purpose'] = data['purpose'].map(lambda x: 'other' if x in ['educational', 'renewable_energy'] else x)

# %% [markdown]
# Применим WOE-преобразование:

# %%
res, woe, iv = WOE(test, 'purpose', 'def')
res
# Out:
#                     DistributionGood  DistributionBad       WOE            IV
# purpose
# car                         0.007785         0.013267 -0.533019  2.921684e-03
# credit_card                 0.188179         0.231194 -0.205866  8.855448e-03
# debt_consolidation          0.616267         0.575233  0.068905  2.827482e-03
# home_improvement            0.050707         0.059408 -0.158373  1.378069e-03
# house                       0.005839         0.005816  0.003885  8.794643e-08
# major_purchase              0.018951         0.023207 -0.202594  8.622222e-04
# medical                     0.010961         0.009337  0.160320  2.602982e-04
# moving                      0.007580         0.006342  0.178445  2.210690e-04
# other                       0.057980         0.050596  0.136220  1.005807e-03
# small_business              0.027351         0.013656  0.694592  9.512598e-03
# vacation                    0.003483         0.005291 -0.418164  7.561315e-04
# wedding                     0.004917         0.006653 -0.302333  5.247786e-04

# %%
print(f'Получившийся IV: {iv}')
# Out:
# Получившийся IV: 0.02912567547478906

# %% [markdown]
# Так как IV > 0.2, будет иметь смысл включить данный признак в дальнейшую классификацию.

# %%
woe_purpose = dict(woe)
def purpose_processing(df):
    values = list(df.unique())
    return df.map(lambda x: 'other' if x in ['educational', 'renewable_energy'] or x not in values else x).map(woe_purpose)

# %%
data_processing = {}
data_processing['purpose'] = purpose_processing

# %% [markdown]
# ## addr_state

# %%
data['addr_state'].isna().sum()
# Out:
# 0

# %%
data['addr_state'].unique()
# Out:
# array(['IL', 'FL', 'NJ', 'MI', 'TX', 'NY', 'CA', 'CO', 'MD', 'LA', 'PA',
#        'TN', 'OH', 'DC', 'SC', 'NC', 'VA', 'NV', 'WA', 'MA', 'UT', 'AZ',
#        'KY', 'AL', 'IN', 'MO', 'CT', 'GA', 'OR', 'OK', 'MT', 'RI', 'NM',
#        'NH', 'MN', 'DE', 'WI', 'KS', 'WV', 'VT', 'AR', 'SD', 'HI', 'AK',
#        'WY', 'MS', 'IA'], dtype=object)

# %%
test['addr_state'] = data['addr_state']

# %% [markdown]
# Применим WOE-преобразование:

# %%
res, woe, iv = WOE(test, 'addr_state', 'def')
iv
# Out:
# 0.017777314918203328

# %% [markdown]
# IV меньше порогового значения, попробуем сгруппировать штаты по субрегионам:

# %%
us_subregions = {'WA': 'Pacific', 'OR': 'Pacific', 'CA': 'Pacific', 'AK': 'Pacific', 'HI': 'Pacific', 
 'MT': 'Mountain', 'ID': 'Mountain', 'WY': 'Mountain', 'NV': 'Mountain', 'UT': 'Mountain', 'CO': 'Mountain', 'AZ': 'Mountain', 'NM': 'Mountain',
 'ND': 'West North Central', 'MN': 'West North Central', 'SD': 'West North Central', 'IA': 'West North Central', 'NE': 'West North Central', 'KS': 'West North Central', 'MO': 'West North Central', 
 'WI': 'East North Central', 'MI': 'East North Central', 'IL': 'East North Central', 'IN': 'East North Central', 'OH': 'East North Central', 
 'PA': 'Middle Atantic', 'NY': 'Middle Atantic', 'NJ': 'Middle Atantic',
 'VT': 'New England', 'NH': 'New England', 'ME': 'New England', 'MA': 'New England', 'CT': 'New England', 'RI': 'New England', 
 'WV': 'South Atantic', 'MD': 'South Atantic', 'DE': 'South Atantic', 'DC': 'South Atantic', 'VA': 'South Atantic', 'NC': 'South Atantic', 'SC': 'South Atantic', 'GA': 'South Atantic', 'FL': 'South Atantic', 
 'KY': 'East South Central', 'TN': 'East South Central', 'MS': 'East South Central', 'AL': 'East South Central', 
 'OK': 'West South Central', 'AR': 'West South Central', 'TX': 'West South Central', 'LA': 'West South Central'
}

# %%
test['addr_state_subr'] = data['addr_state'].map(us_subregions)

# %%
res, woe, iv = WOE(test, 'addr_state_subr', 'def')
res
# Out:
#                     DistributionGood  DistributionBad       WOE        IV
# addr_state_subr
# East North Central          0.124052         0.120528  0.028820  0.000102
# East South Central          0.038517         0.033147  0.150132  0.000806
# Middle Atantic              0.169740         0.155135  0.089974  0.001314
# Mountain                    0.068633         0.078569 -0.135198  0.001343
# New England                 0.046507         0.050888 -0.090027  0.000394
# Pacific                     0.194325         0.205809 -0.057415  0.000659
# South Atantic               0.217578         0.204486  0.062061  0.000813
# West North Central          0.046302         0.046706 -0.008681  0.000004
# West South Central          0.094345         0.104733 -0.104450  0.001085

# %%
iv
# Out:
# 0.00651981454516252

# %% [markdown]
# Получившийся IV слишком мал, так что в дальнейшую классификацию данный признак не пойдет

# %% [markdown]
# ## sub_grade

# %%
data['sub_grade'].isna().sum()
# Out:
# 0

# %%
data['sub_grade'].value_counts()
# Out:
# B3    4714
# B4    4292
# B2    3731
# C1    3562
# C2    3447
# B5    3239
# B1    3205
# C3    3189
# C4    3146
# C5    2899
# A5    2866
# A4    2536
# D1    2417
# D2    2115
# D3    1869
# D4    1682
# A3    1658
# D5    1433
# A2    1376
# A1    1310
# E1    1050
# E2    1043
# E3     847
# E4     755
# E5     641
# F1     503
# F2     415
# F3     380
# F4     232
# F5     217
# G1     129
# G2     112
# G3      75
# G4      47
# G5      37
# Name: sub_grade, dtype: int64

# %% [markdown]
# Так как присутствуют значения признака с малым количеством наблюдений, сгруппируем значения по первой букве.

# %%
test['sub_grade'] = data['sub_grade'].map(lambda x: x[0])

# %%
test['sub_grade'].value_counts().plot(kind='barh');

# %% [markdown]
# Применим WOE-преобразование:

# %%
res, woe, iv = WOE(test, 'sub_grade', 'def')
res
# Out:
#            DistributionGood  DistributionBad       WOE        IV
# sub_grade
# A                  0.057058         0.178750 -1.141920  0.138963
# B                  0.213276         0.332620 -0.444414  0.053038
# C                  0.298504         0.259284  0.140862  0.005525
# D                  0.224134         0.142549  0.452562  0.036923
# E                  0.129891         0.059681  0.777692  0.054602
# F                  0.060848         0.022429  0.998034  0.038344
# G                  0.016288         0.004688  1.245384  0.014446

# %% [markdown]
# Нарисуем график зависимости WOE от признака (здесь вполне можно упорядочить значения признака)

# %%
r = res.sort_values(by='sub_grade')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
iv
# Out:
# 0.3418401462605079

# %% [markdown]
# Зависимость WOE от значений признака получается очень монотонной и IV признака больше порогового значения, так что берем его в классификацию.

# %%
woe_sub_grade = dict(woe)

def sub_grade_processing(df):
    return df.map(lambda x: x[0]).map(woe_sub_grade)

# %%
data_processing['sub_grade'] = sub_grade_processing

# %% [markdown]
# ## home_ownership

# %%
data['home_ownership'].isna().sum()
# Out:
# 0

# %%
data['home_ownership'].value_counts()
# Out:
# MORTGAGE    31414
# RENT        24581
# OWN          5158
# OTHER          10
# NONE            6
# Name: home_ownership, dtype: int64

# %% [markdown]
# Отнесем значение признака NONE к значению OTHER

# %%
test['home_ownership'] = data['home_ownership'].map(lambda x: 'OTHER' if x == 'NONE' else x)

# %% [markdown]
# Применим WOE:

# %%
res, woe, iv = WOE(test, 'home_ownership', 'def')
res
# Out:
#                 DistributionGood  DistributionBad       WOE        IV
# home_ownership
# MORTGAGE                0.466913         0.522419 -0.112328  0.006235
# OTHER                   0.000307         0.000253  0.194940  0.000011
# OWN                     0.086355         0.083938  0.028391  0.000069
# RENT                    0.446425         0.393390  0.126470  0.006707

# %%
print(f'Получившийся IV: {iv}')
# Out:
# Получившийся IV: 0.013021511755184345

# %% [markdown]
# IV меньше порогового значения, в связи с чем не берем признак в дальнейшую классификацию

# %% [markdown]
# ## emp_title

# %%
data['emp_title'].isna().sum()
# Out:
# 3865

# %%
data['emp_title'].value_counts(dropna=False)
# Out:
# NaN                           3865
# Teacher                        505
# Manager                        420
# Registered Nurse               239
# RN                             237
#                               ...
# Chesapeake energy                1
# Commercial Banking Officer       1
# US Navy (Civil Service)          1
# Gemini Sales & Services          1
# receptionoist                    1
# Name: emp_title, Length: 38577, dtype: int64

# %% [markdown]
# 38+ тысяч различных значений признака - не есть хорошо. Попробуем выделить конкретные названия профессий из данных значений.

# %%
def profession(desc, top_prof):
    words = str(desc).split()
    for w in words:
        if w.lower()[-2:] in ('er', 'or', 'ee') or w.lower()[-3:] in ('ant', 'ian', 'ist', 'ent') or w.lower() in top_prof:
            return w.lower()
    if str(desc).lower() in top_prof:
        return str(desc).lower()
    return 'other'

# %%
top_prof = list(data['emp_title'].map(lambda x: str(x).lower()).value_counts(dropna=False)[:50].index)

test['emp_title'] = data['emp_title'].map(lambda x: profession(x, top_prof))
test['emp_title'].value_counts()
# Out:
# other            31231
# nan               3867
# manager           3237
# director           908
# sales              878
#                  ...
# larimer              1
# mechinist            1
# tenant               1
# hollyfrontier        1
# receptionoist        1
# Name: emp_title, Length: 1952, dtype: int64

# %% [markdown]
# При помощи данной обработки удалось сократить количество различных значений в 20 раз. Осталось убрать особенно редкие категории.

# %%
top_prof = list(test['emp_title'].value_counts(dropna=False)[:60].index)

test['emp_title'] = test['emp_title'].map(lambda x: x if x in top_prof else 'other')
test['emp_title'].value_counts()[:20]
# Out:
# other          38536
# nan             3867
# manager         3237
# director         908
# sales            878
# center           843
# assistant        822
# teacher          718
# senior           715
# supervisor       652
# nurse            600
# analyst          587
# engineer         586
# specialist       570
# officer          544
# driver           536
# department       510
# technician       460
# rn               323
# coordinator      320
# Name: emp_title, dtype: int64

# %% [markdown]
# Применим WOE:

# %%
res, woe, iv = WOE(test, 'emp_title', 'def')
iv
# Out:
# 0.02119904036250188

# %% [markdown]
# IV > 0.02, поэтому берем признак в дальнейшую классификацию

# %%
top_prof = list(test['emp_title'].value_counts(dropna=False)[:40].index)
woe_emp_title = dict(woe)

def emp_title_processing(df):
    return df.map(lambda x: profession(x, top_prof)).map(lambda x: x if x in top_prof else 'other').map(woe_emp_title)

# %%
data_processing['emp_title'] = emp_title_processing

# %% [markdown]
# ## installment

# %%
data['installment'].isna().sum()
# Out:
# 0

# %%
data['installment'].describe()
# Out:
# count    61169.000000
# mean       432.671268
# std        243.699189
# min          4.930000
# 25%        257.540000
# 50%        382.490000
# 75%        565.310000
# max       1408.130000
# Name: installment, dtype: float64

# %%
data['installment'].hist(bins=50);

# %% [markdown]
# Напишем алгоритм, группирующий наблюдения таким образом, чтобы в каждый из бакетов попадал хотя бы 1% наблюдений, бакетов было минимум 4 и IV > 0.02.

# %%
def bucketing(data, feature, min_size, max_size, step):
    t = pd.DataFrame()
    t['def'] = data['def']
    buckets = []
    for i in tqdm(range(min_size, max_size + step, step)):
        if int(data[feature].max()) // i < 3:
            continue
        s = data[feature].map(lambda x: int(x) // i)
        d1 = {}
        for j in list(s.unique()):
            d1[j] = j
        for j in range(int(data[feature].max()) // i + 1):
            if j in list(s.unique()):
                k = 0
                while s.value_counts(normalize=True).loc[j] < 0.01:
                    k += 1
                    if j + k > int(data[feature].max()) // i:
                        break
                    if j + k not in list(s.unique()):
                        continue
                    s = s.map(lambda x: j if x == j + k else x)
                    d1[j + k] = j
        for j in range(int(data[feature].max()) // i + 1, -1, -1):
            if j in list(s.unique()) and j >= 1:
                if s.value_counts(normalize=True).loc[j] < 0.01:
                    s = s.map(lambda x: j - 1 if x == j else x)
                    d1[j] = j - 1
        for _ in range(10):
            for el in d1:
                to = d1[d1[el]]
                d1[el] = to
        t[feature] = s
        res, woe, iv = WOE(t, feature, 'def')
        if s.value_counts(normalize=True).min() >= 0.01 and iv >= 0.02 and len(set(d1.values())) >= 4:
            buckets.append((i, d1, iv))
    return buckets

# %%
buckets = bucketing(data, 'installment', 50, 1408, 1)
# Out:
#   0%|          | 0/1359 [00:00<?, ?it/s]

# %% [markdown]
# Нарисуем зависимость значений WOE от значений признака для каждого из бакетов и выберем из них бакет с самой монотонной линейной зависимостью.

# %%
i = 0
fig = plt.figure(figsize=(12, 28))
for b in buckets:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets) // 3 + 1, 3, i)
    test['installment'] = data['installment'].map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'installment', 'def')
    r = res.sort_values(by='installment')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %% [markdown]
# Самой монотонной зависимостью обладает последний график, поэтому возьмем соответствующие ему бакеты

# %%
size_installment = buckets[-1][0]
d_installment = buckets[-1][1]

test['installment'] = data['installment'].map(lambda x: int(x) // size_installment).map(d_installment)
res, woe, iv = WOE(test, 'installment', 'def')
r = res.sort_values(by='installment')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %% [markdown]
# Так как бакет подбирался из условия IV >= 0.02, мы берем признак в дальнейшую классификацию

# %%
woe_installment = dict(woe)

def closest(number, values):
    values_sort = sorted(values)
    if number in values:
        return number
    for i in range(len(values) - 1):
        if values_sort[i] <= number and values_sort[i + 1] > number:
            return values_sort[i]

def installment_processing(df):
    max_value = data['installment'].max()
    values = list(data['installment'].map(lambda x: min(int(x), max_value) // size_installment).unique())
    return df.map(lambda x: closest(min(int(x), max_value) // size_installment, values)).map(d_installment).map(woe_installment)

# %%
data_processing['installment'] = installment_processing

# %% [markdown]
# ## dti

# %%
data['dti'].isna().sum()
# Out:
# 0

# %%
data['dti'].describe()
# Out:
# count    61169.000000
# mean        16.782808
# std          7.531950
# min          0.000000
# 25%         11.180000
# 50%         16.500000
# 75%         22.200000
# max         34.990000
# Name: dti, dtype: float64

# %%
data['dti'].hist(bins=50);

# %%
buckets = bucketing(data, 'dti', 1, 35, 1)
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]

# %%
i = 0
fig = plt.figure(figsize=(12, 16))
for b in buckets:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets) // 3 + 1, 3, i)
    test['dti'] = data['dti'].map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'dti', 'def')
    r = res.sort_values(by='dti')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_dti = buckets[6][0]
d_dti = buckets[6][1]

test['dti'] = data['dti'].map(lambda x: int(x) // size_dti).map(d_dti)
res, woe, iv = WOE(test, 'dti', 'def')
r = res.sort_values(by='dti')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
iv
# Out:
# 0.0395097753690817

# %% [markdown]
# IV > 0.02, поэтому берем данный признак в классификацию

# %%
woe_dti = dict(woe)

def dti_processing(df):
    max_value = data['dti'].max()
    values = list(data['dti'].map(lambda x: min(int(x), max_value) // size_dti).unique())
    return df.map(lambda x: closest(min(int(x), max_value) // size_dti, values)).map(d_dti).map(woe_dti)

# %%
data_processing['dti'] = dti_processing

# %% [markdown]
# ## funded_amnt

# %%
data['funded_amnt'].isna().sum()
# Out:
# 0

# %%
data['funded_amnt'].describe()
# Out:
# count    61169.000000
# mean     14159.664618
# std       8181.125909
# min       1000.000000
# 25%       8000.000000
# 50%      12000.000000
# 75%      20000.000000
# max      35000.000000
# Name: funded_amnt, dtype: float64

# %%
data['funded_amnt'].hist(bins=20);

# %%
buckets = bucketing(data, 'funded_amnt', 1000, 35000, 100)
# Out:
#   0%|          | 0/341 [00:00<?, ?it/s]

# %%
i = 0
fig = plt.figure(figsize=(12, 72))
for b in buckets:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets) // 3 + 1, 3, i)
    test['funded_amnt'] = data['funded_amnt'].map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'funded_amnt', 'def')
    r = res.sort_values(by='funded_amnt')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %% [markdown]
# Выбираем график с самой близкой к монотонной зависимостью

# %%
size_funded_amnt = buckets[41][0]
d_funded_amnt = buckets[41][1]

test['funded_amnt'] = data['funded_amnt'].map(lambda x: int(x) // size_funded_amnt).map(d_funded_amnt)
res, woe, iv = WOE(test, 'funded_amnt', 'def')
r = res.sort_values(by='funded_amnt')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
iv
# Out:
# 0.02089157666433907

# %%
woe_funded_amnt = dict(woe)

def funded_amnt_processing(df):
    max_value = data['funded_amnt'].max()
    values = list(data['funded_amnt'].map(lambda x: min(int(x), max_value) // size_funded_amnt).unique())
    return df.map(lambda x: closest(min(int(x), max_value) // size_funded_amnt, values)).map(d_funded_amnt).map(woe_funded_amnt)

# %%
data_processing['funded_amnt'] = funded_amnt_processing

# %% [markdown]
# ## annual_inc

# %%
data['annual_inc'].isna().sum()
# Out:
# 0

# %%
data['annual_inc'].describe()
# Out:
# count    6.116900e+04
# mean     7.271755e+04
# std      4.954698e+04
# min      6.695000e+03
# 25%      4.500000e+04
# 50%      6.250000e+04
# 75%      8.800000e+04
# max      3.900000e+06
# Name: annual_inc, dtype: float64

# %%
buckets = bucketing(data, 'annual_inc', 7000, 3900000, 5000)
# Out:
#   0%|          | 0/780 [00:00<?, ?it/s]

# %%
i = 0
fig = plt.figure(figsize=(12, 28))
for b in buckets:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets) // 3 + 1, 3, i)
    test['annual_inc'] = data['annual_inc'].map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'annual_inc', 'def')
    r = res.sort_values(by='annual_inc')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_annual_inc = buckets[11][0]
d_annual_inc = buckets[11][1]

test['annual_inc'] = data['annual_inc'].map(lambda x: int(x) // size_annual_inc).map(d_annual_inc)
res, woe, iv = WOE(test, 'annual_inc', 'def')
r = res.sort_values(by='annual_inc')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
woe_annual_inc = dict(woe)

def annual_inc_processing(df):
    max_value = data['annual_inc'].max()
    values = list(data['annual_inc'].map(lambda x: min(int(x), max_value) // size_annual_inc).unique())
    return df.map(lambda x: closest(min(int(x), max_value) // size_annual_inc, values)).map(d_annual_inc).map(woe_annual_inc)

# %%
data_processing['annual_inc'] = annual_inc_processing

# %% [markdown]
# ## emp_length

# %%
data['emp_length'].isna().sum()
# Out:
# 2674

# %%
data['emp_length'].value_counts(dropna=False)
# Out:
# 10.0    19715
# 2.0      5347
# 3.0      4775
# 0.0      4586
# 5.0      4342
# 1.0      3736
# 4.0      3665
# 6.0      3573
# 7.0      3558
# 8.0      2952
# NaN      2674
# 9.0      2246
# Name: emp_length, dtype: int64

# %%
data['emp_length'].value_counts(dropna=False).sort_index().plot(kind='barh');

# %% [markdown]
# Попробуем поочередно заполнить пропуски нулем и медианой и посмотрим на получившиеся WOE

# %%
test['emp_length'] = data['emp_length'].fillna(0)
buckets = bucketing(test, 'emp_length', 1, 10, 1)
buckets
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# []

# %% [markdown]
# Для нуля вовсе не нашлось подходящих бакетов

# %%
test['emp_length'] = data['emp_length'].fillna(0)
res, woe, iv = WOE(test, 'emp_length', 'def')
iv
# Out:
# 0.0033506646393428475

# %% [markdown]
# IV, как мы видим, тоже очень мал

# %%
med = data['emp_length'].median()
test['emp_length'] = data['emp_length'].fillna(med)
buckets = bucketing(test, 'emp_length', 1, 10, 1)
buckets
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# []

# %%
test['emp_length'] = data['emp_length'].fillna(med)
res, woe, iv = WOE(test, 'emp_length', 'def')
iv
# Out:
# 0.0028995275673114997

# %% [markdown]
# Аналогичная ситуация для медианы

# %% [markdown]
# При любом из вариантов заполнения признак оказывается слишком слабым для предсказаний, поэтому мы не будем использовать его для дальнейшей классификации.

# %% [markdown]
# ## term

# %%
data['term'].isna().sum()
# Out:
# 0

# %%
data['term'].value_counts()
# Out:
# 36    45173
# 60    15996
# Name: term, dtype: int64

# %% [markdown]
# Применим WOE-преобразование

# %%
test['term'] = data['term']
res, woe, iv = WOE(test, 'term', 'def')
iv
# Out:
# 0.15813470723119746

# %% [markdown]
# Признак оказался довольно сильным, поэтому оставляем его

# %%
woe_term = dict(woe)

def term_processing(df):
    return df.map(woe_term)

# %%
data_processing['term'] = term_processing

# %% [markdown]
# ## inq_last_6mths

# %%
data['inq_last_6mths'].isna().sum()
# Out:
# 0

# %%
data['inq_last_6mths'].value_counts()
# Out:
# 0    30839
# 1    17097
# 2     8104
# 3     3670
# 4      961
# 5      335
# 6      137
# 7       17
# 8        9
# Name: inq_last_6mths, dtype: int64

# %%
buckets = bucketing(data, 'inq_last_6mths', 1, 8, 1)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
i = 0
fig = plt.figure(figsize=(12, 4))
for b in buckets:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets) // 3 + 1, 3, i)
    test['inq_last_6mths'] = data['inq_last_6mths'].map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'inq_last_6mths', 'def')
    r = res.sort_values(by='inq_last_6mths')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_inq_last_6mths = buckets[0][0]
d_inq_last_6mths = buckets[0][1]

test['inq_last_6mths'] = data['inq_last_6mths'].map(lambda x: int(x) // size_inq_last_6mths).map(d_inq_last_6mths)
res, woe, iv = WOE(test, 'inq_last_6mths', 'def')

# %%
woe_inq_last_6mths = dict(woe)

def inq_last_6mths_processing(df):
    max_value = data['inq_last_6mths'].max()
    values = list(data['inq_last_6mths'].map(lambda x: min(int(x), max_value) // size_inq_last_6mths).unique())
    return df.map(lambda x: closest(min(int(x), max_value) // size_inq_last_6mths, values)).map(d_inq_last_6mths).map(woe_inq_last_6mths)

# %%
data_processing['inq_last_6mths'] = inq_last_6mths_processing

# %% [markdown]
# ## mths_since_recent_inq

# %%
data['mths_since_recent_inq'].isna().sum()
# Out:
# 13529

# %%
data['mths_since_recent_inq'].value_counts(dropna=False)
# Out:
# NaN     13529
# 1.0      5106
# 0.0      4248
# 2.0      4023
# 3.0      3607
# 4.0      3430
# 5.0      3064
# 7.0      2860
# 6.0      2841
# 8.0      2574
# 9.0      2180
# 10.0     1959
# 11.0     1662
# 12.0     1542
# 13.0     1340
# 14.0     1206
# 15.0      986
# 16.0      869
# 17.0      751
# 18.0      671
# 19.0      634
# 20.0      558
# 21.0      474
# 22.0      426
# 23.0      416
# 24.0      213
# Name: mths_since_recent_inq, dtype: int64

# %% [markdown]
# Поочередно заполним пропуски нулем и медианой и посмотрим на получившиеся WOE

# %%
test['mths_since_recent_inq'] = data['mths_since_recent_inq'].fillna(0)
buckets = bucketing(test, 'mths_since_recent_inq', 1, 24, 1)
buckets
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# []

# %%
test['mths_since_recent_inq'] = data['mths_since_recent_inq'].fillna(0)
res, woe, iv = WOE(test, 'mths_since_recent_inq', 'def')
iv
# Out:
# 0.01864579718196492

# %% [markdown]
# Для нуля не нашлось бакетов

# %%
med = data['mths_since_recent_inq'].median()
test['mths_since_recent_inq'] = data['mths_since_recent_inq'].fillna(med)
buckets_med = bucketing(test, 'mths_since_recent_inq', 1, 24, 1)
len(buckets_med)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# 6

# %% [markdown]
# Для медианы нашлось целых 6, выберем из них бакет с самой монотонной зависимостью

# %%
i = 0
fig = plt.figure(figsize=(12, 12))
for b in buckets_med:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_med) // 3 + 1, 3, i)
    med = data['mths_since_recent_inq'].median()
    test['mths_since_recent_inq'] = data['mths_since_recent_inq'].fillna(med).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'mths_since_recent_inq', 'def')
    r = res.sort_values(by='mths_since_recent_inq')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_mths_since_recent_inq = buckets_med[4][0]
d_mths_since_recent_inq = buckets_med[4][1]
med_mths_since_recent_inq = data['mths_since_recent_inq'].median()

test['mths_since_recent_inq'] = data['mths_since_recent_inq'].fillna(med_mths_since_recent_inq).map(lambda x: int(x) // size_mths_since_recent_inq).map(d_mths_since_recent_inq)
res, woe, iv = WOE(test, 'mths_since_recent_inq', 'def')
r = res.sort_values(by='mths_since_recent_inq')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
woe_mths_since_recent_inq = dict(woe)

def mths_since_recent_inq_processing(df):
    max_value = data['mths_since_recent_inq'].max()
    values = list(data['mths_since_recent_inq'].fillna(med_mths_since_recent_inq).map(lambda x: min(int(x), max_value) // size_mths_since_recent_inq).unique())
    return df.fillna(med_mths_since_recent_inq).map(lambda x: closest(min(int(x), max_value) // size_mths_since_recent_inq, values)).map(d_mths_since_recent_inq).map(woe_mths_since_recent_inq)

# %%
data_processing['mths_since_recent_inq'] = mths_since_recent_inq_processing

# %% [markdown]
# ## delinq_2yrs

# %%
data['delinq_2yrs'].isna().sum()
# Out:
# 0

# %%
data['delinq_2yrs'].value_counts(dropna=False)
# Out:
# 0     50997
# 1      6987
# 2      1981
# 3       657
# 4       259
# 5       140
# 6        60
# 7        33
# 8        16
# 9        11
# 10        7
# 11        4
# 13        4
# 18        3
# 14        3
# 12        3
# 15        2
# 16        1
# 29        1
# Name: delinq_2yrs, dtype: int64

# %%
buckets = bucketing(data, 'delinq_2yrs', 1, 29, 1)
buckets
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# []

# %%
res, woe, iv = WOE(data, 'delinq_2yrs', 'def')
iv
# Out:
# 0.002657627030317071

# %% [markdown]
# ## chargeoff_within_12_mths

# %%
data['chargeoff_within_12_mths'].isna().sum()
# Out:
# 0

# %%
data['chargeoff_within_12_mths'].value_counts(normalize=True)
# Out:
# 0    0.994294
# 1    0.005019
# 2    0.000621
# 3    0.000065
# Name: chargeoff_within_12_mths, dtype: float64

# %% [markdown]
# Так как в 99.5% случаев признак принимает одно и то же значение, кажется, имеет смысл его исключить.

# %% [markdown]
# ## num_accts_ever_120_pd

# %%
data['num_accts_ever_120_pd'].isna().sum()
# Out:
# 11941

# %%
data['num_accts_ever_120_pd'].value_counts(dropna=False)
# Out:
# 0.0     39427
# NaN     11941
# 1.0      5561
# 2.0      2099
# 3.0       898
# 4.0       518
# 5.0       291
# 6.0       197
# 7.0        99
# 8.0        45
# 9.0        37
# 10.0       24
# 11.0       14
# 12.0       10
# 14.0        4
# 13.0        1
# 20.0        1
# 15.0        1
# 29.0        1
# Name: num_accts_ever_120_pd, dtype: int64

# %%
test['num_accts_ever_120_pd'] = data['num_accts_ever_120_pd'].fillna(0)
buckets = bucketing(test, 'num_accts_ever_120_pd', 1, 29, 1)
buckets
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# []

# %%
med = data['num_accts_ever_120_pd'].median()
test['num_accts_ever_120_pd'] = data['num_accts_ever_120_pd'].fillna(med)
buckets = bucketing(test, 'num_accts_ever_120_pd', 1, 29, 1)
buckets
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# []

# %%
res, woe, iv = WOE(data, 'num_accts_ever_120_pd', 'def')
iv
# Out:
# 0.0029619567844419298

# %% [markdown]
# ## num_tl_90g_dpd_24m

# %%
data['num_tl_90g_dpd_24m'].isna().sum()
# Out:
# 11941

# %%
data['num_tl_90g_dpd_24m'].value_counts(dropna=False)
# Out:
# 0.0     46585
# NaN     11941
# 1.0      2015
# 2.0       434
# 3.0        87
# 4.0        52
# 5.0        16
# 6.0        15
# 8.0         6
# 10.0        4
# 15.0        3
# 14.0        2
# 7.0         2
# 11.0        2
# 13.0        1
# 9.0         1
# 18.0        1
# 12.0        1
# 20.0        1
# Name: num_tl_90g_dpd_24m, dtype: int64

# %%
test['num_tl_90g_dpd_24m'] = data['num_tl_90g_dpd_24m'].fillna(0)
buckets = bucketing(test, 'num_tl_90g_dpd_24m', 1, 20, 1)
buckets
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# []

# %%
med = data['num_tl_90g_dpd_24m'].median()
test['num_tl_90g_dpd_24m'] = data['num_tl_90g_dpd_24m'].fillna(med)
buckets = bucketing(test, 'num_tl_90g_dpd_24m', 1, 20, 1)
buckets
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# []

# %%
res, woe, iv = WOE(data, 'num_tl_90g_dpd_24m', 'def')
iv
# Out:
# 0.0016649229464915502

# %% [markdown]
# ## acc_open_past_24mths

# %%
data['acc_open_past_24mths'].isna().sum()
# Out:
# 7886

# %%
data['acc_open_past_24mths'].value_counts(dropna=False)
# Out:
# 3.0     8829
# 2.0     8133
# 4.0     7990
# NaN     7886
# 5.0     6470
# 1.0     5857
# 6.0     4718
# 7.0     3269
# 0.0     2689
# 8.0     2104
# 9.0     1299
# 10.0     751
# 11.0     455
# 12.0     273
# 13.0     172
# 14.0     115
# 15.0      56
# 16.0      39
# 17.0      25
# 18.0      14
# 19.0      11
# 20.0       6
# 21.0       4
# 23.0       1
# 33.0       1
# 28.0       1
# 22.0       1
# Name: acc_open_past_24mths, dtype: int64

# %%
test['acc_open_past_24mths'] = data['acc_open_past_24mths'].fillna(0)
buckets_zero = bucketing(test, 'acc_open_past_24mths', 1, 30, 1)
len(buckets_zero)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 4

# %%
med = data['acc_open_past_24mths'].median()
test['acc_open_past_24mths'] = data['acc_open_past_24mths'].fillna(med)
buckets_med = bucketing(test, 'acc_open_past_24mths', 1, 30, 1)
len(buckets_med)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 4

# %% [markdown]
# Построим графики и для заполнения нулем и для заполнения медианой и выберем из них самый монотонный.

# %%
i = 0
fig = plt.figure(figsize=(12, 8))
for b in buckets_zero:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_zero) // 3 + 1, 3, i)
    test['acc_open_past_24mths'] = data['acc_open_past_24mths'].fillna(0).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'acc_open_past_24mths', 'def')
    r = res.sort_values(by='acc_open_past_24mths')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
i = 0
fig = plt.figure(figsize=(12, 8))
for b in buckets_med:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_med) // 3 + 1, 3, i)
    med = data['acc_open_past_24mths'].median()
    test['acc_open_past_24mths'] = data['acc_open_past_24mths'].fillna(med).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'acc_open_past_24mths', 'def')
    r = res.sort_values(by='acc_open_past_24mths')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_acc_open_past_24mths = buckets_zero[3][0]
d_acc_open_past_24mths = buckets_zero[3][1]

test['acc_open_past_24mths'] = data['acc_open_past_24mths'].fillna(0).map(lambda x: int(x) // size_acc_open_past_24mths).map(d_acc_open_past_24mths)
res, woe, iv = WOE(test, 'acc_open_past_24mths', 'def')
r = res.sort_values(by='acc_open_past_24mths')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
woe_acc_open_past_24mths = dict(woe)

def acc_open_past_24mths_processing(df):
    max_value = data['acc_open_past_24mths'].max()
    values = list(data['acc_open_past_24mths'].fillna(0).map(lambda x: min(int(x), max_value) // size_acc_open_past_24mths).unique())
    return df.fillna(0).map(lambda x: closest(min(int(x), max_value) // size_acc_open_past_24mths, values)).map(d_acc_open_past_24mths).map(woe_acc_open_past_24mths)

# %%
data_processing['acc_open_past_24mths'] = acc_open_past_24mths_processing

# %% [markdown]
# ## avg_cur_bal

# %%
data['avg_cur_bal'].isna().sum()
# Out:
# 11945

# %%
data['avg_cur_bal'].describe()
# Out:
# count     49224.000000
# mean      13734.641049
# std       16054.221586
# min           0.000000
# 25%        3025.000000
# 50%        7847.000000
# 75%       19527.000000
# max      354015.000000
# Name: avg_cur_bal, dtype: float64

# %%
test['avg_cur_bal'] = data['avg_cur_bal'].fillna(0)
buckets_zero = bucketing(test, 'avg_cur_bal', 10000, 354000, 5000)
len(buckets_zero)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
# 3

# %%
med = data['avg_cur_bal'].median()
test['avg_cur_bal'] = data['avg_cur_bal'].fillna(med)
buckets_med = bucketing(test, 'avg_cur_bal', 10000, 354000, 5000)
len(buckets_med)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
# 3

# %%
i = 0
fig = plt.figure(figsize=(12, 8))
for b in buckets_zero:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_zero) // 3 + 1, 3, i)
    test['avg_cur_bal'] = data['avg_cur_bal'].fillna(0).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'avg_cur_bal', 'def')
    r = res.sort_values(by='avg_cur_bal')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
i = 0
fig = plt.figure(figsize=(12, 8))
for b in buckets_med:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_med) // 3 + 1, 3, i) 
    med = data['avg_cur_bal'].median()
    test['avg_cur_bal'] = data['avg_cur_bal'].fillna(med).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'avg_cur_bal', 'def')
    r = res.sort_values(by='avg_cur_bal')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_avg_cur_bal = buckets_zero[1][0]
d_avg_cur_bal = buckets_zero[1][1]

test['avg_cur_bal'] = data['avg_cur_bal'].fillna(0).map(lambda x: int(x) // size_avg_cur_bal).map(d_avg_cur_bal)
res, woe, iv = WOE(test, 'avg_cur_bal', 'def')
r = res.sort_values(by='avg_cur_bal')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
woe_avg_cur_bal = dict(woe)

def avg_cur_bal_processing(df):
    max_value = data['avg_cur_bal'].max()
    values = list(data['avg_cur_bal'].fillna(0).map(lambda x: min(int(x), max_value) // size_avg_cur_bal).unique())
    return df.fillna(0).map(lambda x: closest(min(int(x), max_value) // size_avg_cur_bal, values)).map(d_avg_cur_bal).map(woe_avg_cur_bal)

# %%
data_processing['avg_cur_bal'] = avg_cur_bal_processing

# %% [markdown]
# ## tot_hi_cred_lim

# %%
data['tot_hi_cred_lim'].isna().sum()
# Out:
# 11941

# %%
data['tot_hi_cred_lim'].describe()
# Out:
# count    4.922800e+04
# mean     1.671557e+05
# std      1.699201e+05
# min      0.000000e+00
# 25%      4.550000e+04
# 50%      1.110695e+05
# 75%      2.458785e+05
# max      9.999999e+06
# Name: tot_hi_cred_lim, dtype: float64

# %%
test['tot_hi_cred_lim'] = data['tot_hi_cred_lim'].fillna(0)
buckets_zero = bucketing(test, 'tot_hi_cred_lim', 10000, 10000000, 10000)
len(buckets_zero)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 22

# %%
med = data['tot_hi_cred_lim'].median()
test['tot_hi_cred_lim'] = data['tot_hi_cred_lim'].fillna(med)
buckets_med = bucketing(test, 'tot_hi_cred_lim', 10000, 10000000, 10000)
len(buckets_med)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 22

# %%
i = 0
fig = plt.figure(figsize=(12, 32))
for b in buckets_zero:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_zero) // 3 + 1, 3, i)
    test['tot_hi_cred_lim'] = data['tot_hi_cred_lim'].fillna(0).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'tot_hi_cred_lim', 'def')
    r = res.sort_values(by='tot_hi_cred_lim')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
i = 0
fig = plt.figure(figsize=(12, 32))
for b in buckets_med:
    size = b[0]
    d = b[1]
    i += 1
    plt.subplot(len(buckets_med) // 3 + 1, 3, i) 
    med = data['tot_hi_cred_lim'].median()
    test['tot_hi_cred_lim'] = data['tot_hi_cred_lim'].fillna(med).map(lambda x: int(x) // size).map(d)
    res, woe, iv = WOE(test, 'tot_hi_cred_lim', 'def')
    r = res.sort_values(by='tot_hi_cred_lim')
    x = list(r.index)
    y = r['WOE']
    plt.plot(x, y)
    plt.xticks(x);

# %%
size_tot_hi_cred_lim = buckets_med[13][0]
d_tot_hi_cred_lim = buckets_med[13][1]
med_tot_hi_cred_lim = data['tot_hi_cred_lim'].median()

test['tot_hi_cred_lim'] = data['tot_hi_cred_lim'].fillna(med_tot_hi_cred_lim).map(lambda x: int(x) // size_tot_hi_cred_lim).map(d_tot_hi_cred_lim)
res, woe, iv = WOE(test, 'tot_hi_cred_lim', 'def')
r = res.sort_values(by='tot_hi_cred_lim')
x = list(r.index)
y = r['WOE']
plt.plot(x, y)
plt.xticks(x);

# %%
woe_tot_hi_cred_lim = dict(woe)

def tot_hi_cred_lim_processing(df):
    max_value = data['tot_hi_cred_lim'].max()
    values = list(data['tot_hi_cred_lim'].fillna(med_tot_hi_cred_lim).map(lambda x: min(int(x), max_value) // size_tot_hi_cred_lim).unique())
    return df.fillna(med_tot_hi_cred_lim).map(lambda x: closest(min(int(x), max_value) // size_tot_hi_cred_lim, values)).map(d_tot_hi_cred_lim).map(woe_tot_hi_cred_lim)

# %%
data_processing['tot_hi_cred_lim'] = tot_hi_cred_lim_processing

# %% [markdown]
# ## delinq_amnt

# %%
data['delinq_amnt'].isna().sum()
# Out:
# 0

# %%
data['delinq_amnt'].value_counts(normalize=True)
# Out:
# 0        0.997924
# 25       0.000098
# 30       0.000098
# 65000    0.000049
# 254      0.000033
#            ...
# 1420     0.000016
# 1921     0.000016
# 56       0.000016
# 94       0.000016
# 10       0.000016
# Name: delinq_amnt, Length: 110, dtype: float64

# %% [markdown]
# Так как в 99.7% случаев признак принимает одно и то же значение, исключим его.

# %% [markdown]
# ## Финальное преобразование

# %%
X_train = pd.DataFrame()
for column in data.columns:
    if column in data_processing:
        X_train[column] = data_processing[column](data[column])
y_train = data['def']

# %% [markdown]
# Проверим корреляцию между признаками:

# %%
sns.heatmap(X_train.corr(), cmap="YlGnBu");

# %% [markdown]
# Видно, что многие признаки довольно сильно скоррелированы. Составим пары из всех признаков с корреляцией > 0.5 и сравним их IV внутри каждой пары, после чего удалим признаки с меньшими.

# %%
pairs = []
corr = X_train.corr()
for ind in X_train.columns:
    for col in X_train.columns:
        if ind != col and corr.loc[ind][col] > 0.5 and [col, ind] not in pairs:
            pairs.append([ind, col])

# %%
iv_s = {}
X_iv = X_train.copy()
X_iv['def'] = y_train
for feature in X_train.columns:
    iv_s[feature] = WOE(X_iv, feature, 'def')[2]

# %%
to_drop = set()
for a, b in pairs:
    if iv_s[a] < iv_s[b]:
        to_drop.add(a)
    elif iv_s[a] > iv_s[b]:
        to_drop.add(b)
    else:
        print('Error')

# %%
X_train = X_train.drop(columns=to_drop)
X_train.head()
# Out:
#     purpose  sub_grade  emp_title       dti  funded_amnt  annual_inc  \
# 0  0.068905   0.140862  -0.017123  0.017529    -0.181047    0.158423
# 1  0.068905  -0.444414  -0.017123  0.017529     0.052216   -0.128896
# 2  0.068905  -0.444414  -0.017123  0.017529     0.199520   -0.128896
# 3  0.068905   0.140862  -0.017123  0.017529    -0.071564    0.158423
# 4 -0.205866   0.452562  -0.114672  0.186543    -0.071564   -0.128896
#
#        term  inq_last_6mths  acc_open_past_24mths  avg_cur_bal
# 0 -0.274275        0.308701             -0.160785     0.081537
# 1 -0.274275        0.082066              0.120760    -0.133978
# 2 -0.274275       -0.168214              0.120760     0.081537
# 3 -0.274275        0.082066             -0.160785     0.081537
# 4 -0.274275        0.308701              0.120760     0.081537

# %%
def to_dataset(data):
    X = pd.DataFrame()
    for column in data.columns:
        if column in data_processing:
            X[column] = data_processing[column](data[column])
    y = data['def']
    return X.drop(columns=to_drop), y

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# При помощи кросс-валидации подберем оптимальный коэффицент регуляризации

# %%
searcher = GridSearchCV(estimator=LogisticRegression(), param_grid={'penalty': ['l2', None], 'C': [1, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]}, cv=5,
                        scoring='roc_auc', verbose=10)
searcher.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START C=1, penalty=l2............................................
# [CV 1/5; 1/24] END .............C=1, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 1/24] START C=1, penalty=l2............................................
# [CV 2/5; 1/24] END .............C=1, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 1/24] START C=1, penalty=l2............................................
# [CV 3/5; 1/24] END .............C=1, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 1/24] START C=1, penalty=l2............................................
# [CV 4/5; 1/24] END .............C=1, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 1/24] START C=1, penalty=l2............................................
# [CV 5/5; 1/24] END .............C=1, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 2/24] START C=1, penalty=None..........................................
# [CV 1/5; 2/24] END ...........C=1, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 2/24] START C=1, penalty=None..........................................
# [CV 2/5; 2/24] END ...........C=1, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 2/24] START C=1, penalty=None..........................................
# [CV 3/5; 2/24] END ...........C=1, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 2/24] START C=1, penalty=None..........................................
# [CV 4/5; 2/24] END ...........C=1, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 2/24] START C=1, penalty=None..........................................
# [CV 5/5; 2/24] END ...........C=1, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 3/24] START C=10, penalty=l2...........................................
# [CV 1/5; 3/24] END ............C=10, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 3/24] START C=10, penalty=l2...........................................
# [CV 2/5; 3/24] END ............C=10, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 3/24] START C=10, penalty=l2...........................................
# [CV 3/5; 3/24] END ............C=10, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 3/24] START C=10, penalty=l2...........................................
# [CV 4/5; 3/24] END ............C=10, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 3/24] START C=10, penalty=l2...........................................
# [CV 5/5; 3/24] END ............C=10, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 4/24] START C=10, penalty=None.........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 4/24] END ..........C=10, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 4/24] START C=10, penalty=None.........................................
# [CV 2/5; 4/24] END ..........C=10, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 4/24] START C=10, penalty=None.........................................
# [CV 3/5; 4/24] END ..........C=10, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 4/24] START C=10, penalty=None.........................................
# [CV 4/5; 4/24] END ..........C=10, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 4/24] START C=10, penalty=None.........................................
# [CV 5/5; 4/24] END ..........C=10, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 5/24] START C=50, penalty=l2...........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 5/24] END ............C=50, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 5/24] START C=50, penalty=l2...........................................
# [CV 2/5; 5/24] END ............C=50, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 5/24] START C=50, penalty=l2...........................................
# [CV 3/5; 5/24] END ............C=50, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 5/24] START C=50, penalty=l2...........................................
# [CV 4/5; 5/24] END ............C=50, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 5/24] START C=50, penalty=l2...........................................
# [CV 5/5; 5/24] END ............C=50, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 6/24] START C=50, penalty=None.........................................
# [CV 1/5; 6/24] END ..........C=50, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 6/24] START C=50, penalty=None.........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 6/24] END ..........C=50, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 6/24] START C=50, penalty=None.........................................
# [CV 3/5; 6/24] END ..........C=50, penalty=None;, score=0.680 total time=   0.1s
# [CV 4/5; 6/24] START C=50, penalty=None.........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5; 6/24] END ..........C=50, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 6/24] START C=50, penalty=None.........................................
# [CV 5/5; 6/24] END ..........C=50, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 7/24] START C=100, penalty=l2..........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 7/24] END ...........C=100, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 7/24] START C=100, penalty=l2..........................................
# [CV 2/5; 7/24] END ...........C=100, penalty=l2;, score=0.683 total time=   0.1s
# [CV 3/5; 7/24] START C=100, penalty=l2..........................................
# [CV 3/5; 7/24] END ...........C=100, penalty=l2;, score=0.680 total time=   0.1s
# [CV 4/5; 7/24] START C=100, penalty=l2..........................................
# [CV 4/5; 7/24] END ...........C=100, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 7/24] START C=100, penalty=l2..........................................
# [CV 5/5; 7/24] END ...........C=100, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 8/24] START C=100, penalty=None........................................
# [CV 1/5; 8/24] END .........C=100, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 8/24] START C=100, penalty=None........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 8/24] END .........C=100, penalty=None;, score=0.683 total time=   0.1s
# [CV 3/5; 8/24] START C=100, penalty=None........................................
# [CV 3/5; 8/24] END .........C=100, penalty=None;, score=0.680 total time=   0.1s
# [CV 4/5; 8/24] START C=100, penalty=None........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5; 8/24] END .........C=100, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 8/24] START C=100, penalty=None........................................
# [CV 5/5; 8/24] END .........C=100, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 9/24] START C=500, penalty=l2..........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 9/24] END ...........C=500, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 9/24] START C=500, penalty=l2..........................................
# [CV 2/5; 9/24] END ...........C=500, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 9/24] START C=500, penalty=l2..........................................
# [CV 3/5; 9/24] END ...........C=500, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 9/24] START C=500, penalty=l2..........................................
# [CV 4/5; 9/24] END ...........C=500, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 9/24] START C=500, penalty=l2..........................................
# [CV 5/5; 9/24] END ...........C=500, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 10/24] START C=500, penalty=None.......................................
# [CV 1/5; 10/24] END ........C=500, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 10/24] START C=500, penalty=None.......................................
# [CV 2/5; 10/24] END ........C=500, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 10/24] START C=500, penalty=None.......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/5; 10/24] END ........C=500, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 10/24] START C=500, penalty=None.......................................
# [CV 4/5; 10/24] END ........C=500, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 10/24] START C=500, penalty=None.......................................
# [CV 5/5; 10/24] END ........C=500, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 11/24] START C=1000, penalty=l2........................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 11/24] END .........C=1000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 11/24] START C=1000, penalty=l2........................................
# [CV 2/5; 11/24] END .........C=1000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 11/24] START C=1000, penalty=l2........................................
# [CV 3/5; 11/24] END .........C=1000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 11/24] START C=1000, penalty=l2........................................
# [CV 4/5; 11/24] END .........C=1000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 11/24] START C=1000, penalty=l2........................................
# [CV 5/5; 11/24] END .........C=1000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 12/24] START C=1000, penalty=None......................................
# [CV 1/5; 12/24] END .......C=1000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 12/24] START C=1000, penalty=None......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 12/24] END .......C=1000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 12/24] START C=1000, penalty=None......................................
# [CV 3/5; 12/24] END .......C=1000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 12/24] START C=1000, penalty=None......................................
# [CV 4/5; 12/24] END .......C=1000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 12/24] START C=1000, penalty=None......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 5/5; 12/24] END .......C=1000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 13/24] START C=5000, penalty=l2........................................
# [CV 1/5; 13/24] END .........C=5000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 13/24] START C=5000, penalty=l2........................................
# [CV 2/5; 13/24] END .........C=5000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 13/24] START C=5000, penalty=l2........................................
# [CV 3/5; 13/24] END .........C=5000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 13/24] START C=5000, penalty=l2........................................
# [CV 4/5; 13/24] END .........C=5000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 13/24] START C=5000, penalty=l2........................................
# [CV 5/5; 13/24] END .........C=5000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 14/24] START C=5000, penalty=None......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 14/24] END .......C=5000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 14/24] START C=5000, penalty=None......................................
# [CV 2/5; 14/24] END .......C=5000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 14/24] START C=5000, penalty=None......................................
# [CV 3/5; 14/24] END .......C=5000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 14/24] START C=5000, penalty=None......................................
# [CV 4/5; 14/24] END .......C=5000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 14/24] START C=5000, penalty=None......................................
# [CV 5/5; 14/24] END .......C=5000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 15/24] START C=10000, penalty=l2.......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 15/24] END ........C=10000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 15/24] START C=10000, penalty=l2.......................................
# [CV 2/5; 15/24] END ........C=10000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 15/24] START C=10000, penalty=l2.......................................
# [CV 3/5; 15/24] END ........C=10000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 15/24] START C=10000, penalty=l2.......................................
# [CV 4/5; 15/24] END ........C=10000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 15/24] START C=10000, penalty=l2.......................................
# [CV 5/5; 15/24] END ........C=10000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 16/24] START C=10000, penalty=None.....................................
# [CV 1/5; 16/24] END ......C=10000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 16/24] START C=10000, penalty=None.....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 16/24] END ......C=10000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 16/24] START C=10000, penalty=None.....................................
# [CV 3/5; 16/24] END ......C=10000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 16/24] START C=10000, penalty=None.....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5; 16/24] END ......C=10000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 16/24] START C=10000, penalty=None.....................................
# [CV 5/5; 16/24] END ......C=10000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 17/24] START C=50000, penalty=l2.......................................
# [CV 1/5; 17/24] END ........C=50000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 17/24] START C=50000, penalty=l2.......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 17/24] END ........C=50000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 17/24] START C=50000, penalty=l2.......................................
# [CV 3/5; 17/24] END ........C=50000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 17/24] START C=50000, penalty=l2.......................................
# [CV 4/5; 17/24] END ........C=50000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 17/24] START C=50000, penalty=l2.......................................
# [CV 5/5; 17/24] END ........C=50000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 18/24] START C=50000, penalty=None.....................................
# [CV 1/5; 18/24] END ......C=50000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 18/24] START C=50000, penalty=None.....................................
# [CV 2/5; 18/24] END ......C=50000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 18/24] START C=50000, penalty=None.....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/5; 18/24] END ......C=50000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 18/24] START C=50000, penalty=None.....................................
# [CV 4/5; 18/24] END ......C=50000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 18/24] START C=50000, penalty=None.....................................
# [CV 5/5; 18/24] END ......C=50000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 19/24] START C=100000, penalty=l2......................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 19/24] END .......C=100000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 19/24] START C=100000, penalty=l2......................................
# [CV 2/5; 19/24] END .......C=100000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 19/24] START C=100000, penalty=l2......................................
# [CV 3/5; 19/24] END .......C=100000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 19/24] START C=100000, penalty=l2......................................
# [CV 4/5; 19/24] END .......C=100000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 19/24] START C=100000, penalty=l2......................................
# [CV 5/5; 19/24] END .......C=100000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 20/24] START C=100000, penalty=None....................................
# [CV 1/5; 20/24] END .....C=100000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 20/24] START C=100000, penalty=None....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 20/24] END .....C=100000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 20/24] START C=100000, penalty=None....................................
# [CV 3/5; 20/24] END .....C=100000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 20/24] START C=100000, penalty=None....................................
# [CV 4/5; 20/24] END .....C=100000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 20/24] START C=100000, penalty=None....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 5/5; 20/24] END .....C=100000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 21/24] START C=500000, penalty=l2......................................
# [CV 1/5; 21/24] END .......C=500000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 21/24] START C=500000, penalty=l2......................................
# [CV 2/5; 21/24] END .......C=500000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 21/24] START C=500000, penalty=l2......................................
# [CV 3/5; 21/24] END .......C=500000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 21/24] START C=500000, penalty=l2......................................
# [CV 4/5; 21/24] END .......C=500000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 21/24] START C=500000, penalty=l2......................................
# [CV 5/5; 21/24] END .......C=500000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 22/24] START C=500000, penalty=None....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/5; 22/24] END .....C=500000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 22/24] START C=500000, penalty=None....................................
# [CV 2/5; 22/24] END .....C=500000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 22/24] START C=500000, penalty=None....................................
# [CV 3/5; 22/24] END .....C=500000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 22/24] START C=500000, penalty=None....................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5; 22/24] END .....C=500000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 22/24] START C=500000, penalty=None....................................
# [CV 5/5; 22/24] END .....C=500000, penalty=None;, score=0.686 total time=   0.0s
# [CV 1/5; 23/24] START C=1000000, penalty=l2.....................................
# [CV 1/5; 23/24] END ......C=1000000, penalty=l2;, score=0.704 total time=   0.0s
# [CV 2/5; 23/24] START C=1000000, penalty=l2.....................................
# [CV 2/5; 23/24] END ......C=1000000, penalty=l2;, score=0.683 total time=   0.0s
# [CV 3/5; 23/24] START C=1000000, penalty=l2.....................................
# [CV 3/5; 23/24] END ......C=1000000, penalty=l2;, score=0.680 total time=   0.0s
# [CV 4/5; 23/24] START C=1000000, penalty=l2.....................................
# [CV 4/5; 23/24] END ......C=1000000, penalty=l2;, score=0.690 total time=   0.0s
# [CV 5/5; 23/24] START C=1000000, penalty=l2.....................................
# [CV 5/5; 23/24] END ......C=1000000, penalty=l2;, score=0.686 total time=   0.0s
# [CV 1/5; 24/24] START C=1000000, penalty=None...................................
# [CV 1/5; 24/24] END ....C=1000000, penalty=None;, score=0.704 total time=   0.0s
# [CV 2/5; 24/24] START C=1000000, penalty=None...................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5; 24/24] END ....C=1000000, penalty=None;, score=0.683 total time=   0.0s
# [CV 3/5; 24/24] START C=1000000, penalty=None...................................
# [CV 3/5; 24/24] END ....C=1000000, penalty=None;, score=0.680 total time=   0.0s
# [CV 4/5; 24/24] START C=1000000, penalty=None...................................
# [CV 4/5; 24/24] END ....C=1000000, penalty=None;, score=0.690 total time=   0.0s
# [CV 5/5; 24/24] START C=1000000, penalty=None...................................
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\ProgramData\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 5/5; 24/24] END ....C=1000000, penalty=None;, score=0.686 total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 50, 100, 500, 1000, 5000, 10000, 50000,
#                                100000, 500000, 1000000],
#                          'penalty': ['l2', None]},
#              scoring='roc_auc', verbose=10)

# %%
searcher.best_params_
# Out:
# {'C': 1, 'penalty': 'l2'}

# %% [markdown]
# Обучим модель с подобранным гиперпараметром:

# %%
lr = LogisticRegression(penalty='l2', C=1)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1)

# %% [markdown]
# # Validation

# %%
val = pd.read_csv('vl_for_students.csv')

val.head()
# Out:
#       issue_d             purpose addr_state sub_grade home_ownership  \
# 0  2015-04-01  debt_consolidation         CT        C5       MORTGAGE
# 1  2014-09-01  debt_consolidation         WI        D1       MORTGAGE
# 2  2014-10-01  debt_consolidation         AZ        D3            OWN
# 3  2014-07-01  debt_consolidation         FL        C2       MORTGAGE
# 4  2015-01-01         credit_card         CA        B5            OWN
#
#               emp_title  installment    dti  funded_amnt  annual_inc  ...  \
# 0              Director       689.89  17.22        20000    270000.0  ...
# 1  Underwriting Manager       578.68  25.10        24000     84000.0  ...
# 2   Haul Truck Operator       534.72  17.97        15000     59028.0  ...
# 3         Duct mechanic       203.18  15.82         6000     46280.0  ...
# 4              Engineer      1162.34  14.37        35000    150000.0  ...
#
#    mths_since_recent_inq  delinq_2yrs  chargeoff_within_12_mths  \
# 0                    0.0            1                         0
# 1                    NaN            0                         0
# 2                    4.0            1                         0
# 3                    2.0            0                         0
# 4                    NaN            2                         1
#
#    num_accts_ever_120_pd  num_tl_90g_dpd_24m  acc_open_past_24mths  \
# 0                      0                   0                     8
# 1                      0                   0                     2
# 2                      3                   0                     8
# 3                      2                   0                     3
# 4                      2                   2                     2
#
#    avg_cur_bal  tot_hi_cred_lim  delinq_amnt  def
# 0        47255         820469.0            0    0
# 1        17604         271531.0            0    1
# 2         3697          56655.0            0    0
# 3         5875          41036.0            0    0
# 4        55056         576535.0            0    0
#
# [5 rows x 23 columns]

# %%
X_val, y_val = to_dataset(val)

# %% [markdown]
# ## Тест M2.1: Эффективность ранжирования всей модели

# %%
fpr, tpr, thresholds = roc_curve(y_val, lr.predict_proba(X_val)[:, 1])

plt.plot(fpr, tpr, color='green')
plt.plot(np.arange(0, 1.05, 0.05), np.arange(0, 1.05, 0.05), color='green')
for i in range(len(fpr)):
    if i % 30 == 0:
        plt.plot([fpr[i], fpr[i]], [fpr[i], tpr[i]], color='green')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate');

# %%
print(f'Коэффицент Джини: {2 * roc_auc_score(y_val, lr.predict_proba(X_val)[:, 1]) - 1}')
# Out:
# Коэффицент Джини: 0.35861796550849045

# %% [markdown]
# ## Тест M2.2: Эффективность ранжирования отдельных факторов

# %%
gini_for_features = {}
for column in X_val.columns:
    X_zeros = pd.DataFrame(np.zeros(X_val.shape), columns=X_val.columns)
    X_zeros[column] = X_val[column]
    gini_for_features[column] = 2 * roc_auc_score(y_val, lr.predict_proba(X_zeros)[:, 1]) - 1

plt.figure(figsize=(12, 6))
pd.Series(gini_for_features).sort_values(ascending=False).plot(kind='bar', color='green')
plt.ylim([0.0, 0.35])
plt.ylabel('Gini')
plt.grid(axis='y', alpha=0.5);

# %% [markdown]
# ## Тест M2.5: Анализ вкладов факторов в формирование Джини модели

# %%
gini_uplifts = {}
X_zeros = pd.DataFrame(np.zeros(X_val.shape), columns=X_val.columns)
columns_sorted = list(pd.Series(gini_for_features).sort_values(ascending=False).index)
for column in columns_sorted:
    X_zeros[column] = X_val[column]
    gini_uplifts[column] = 2 * roc_auc_score(y_val, lr.predict_proba(X_zeros)[:, 1]) - 1
    
plt.figure(figsize=(12, 6))
pd.Series(gini_uplifts).sort_values().plot(kind='bar', color='green')
pd.Series([0] + list(pd.Series(gini_uplifts).sort_values())[:-1]).sort_values().plot(kind='bar', color='white')
pd.Series(gini_for_features).sort_values(ascending=False).plot(kind='line', color='blue')
plt.ylim([0.0, 0.37])
plt.ylabel('Gini')
plt.xticks(rotation=90)
plt.grid(axis='y', alpha=0.5);

# %% [markdown]
# ## Тест M2.4: Динамика коэффициента Джини

# %%
gini_monthly = {}
obs_number = {}
dates = sorted(val['issue_d'].unique())
for date in dates:
    X_monthly, y_monthly = to_dataset(val[val['issue_d'] == date])
    gini_monthly[date] = 2 * roc_auc_score(y_monthly, lr.predict_proba(X_monthly)[:, 1]) - 1
    obs_number[date] = X_monthly.shape[0]

fig, ax1 = plt.subplots()
ax1.set_ylabel('Observations number')
ax1.bar(x=list(pd.Series(obs_number).sort_index().index), height=list(pd.Series(obs_number).sort_index().values), alpha=0.5, color='green')
plt.xticks(rotation=90)
ax2 = ax1.twinx()
ax2.set_ylabel('Gini')
ax2.plot(pd.Series(gini_monthly).sort_index(), color='red')
fig.tight_layout();

# %% [markdown]
# ## Тест M4.1: Сравнение прогнозного и фактического TR (Target Rate) на уровне выборки

# %%
print(f'Среднее арифметическое значение вероятности наступления целевого события: {lr.predict_proba(X_val)[:, 1].mean()}')
# Out:
# Среднее арифметическое значение вероятности наступления целевого события: 0.17044298399697358

# %%
print(f'Средний уровень целевого события: {y_val.mean()}')
# Out:
# Средний уровень целевого события: 0.1767357830706247

# %%
abs(y_val.mean() - lr.predict_proba(X_val)[:, 1].mean()) / y_val.mean()
# Out:
# 0.03560568756546877

# %% [markdown]
# ## Тест M4.2: Тест формы калибровочной кривой

# %%
cal_curve_pre = pd.DataFrame()
cal_curve_pre['probas'] = lr.predict_proba(X_val)[:, 1]
cal_curve_pre['true'] = y_val
cal_curve_pre = cal_curve_pre.sort_values(by='probas')
cal_curve_pre['ind'] = np.arange(0, cal_curve_pre.shape[0])
cal_curve_pre['bucket'] = cal_curve_pre['ind'] // 6000
cal_curve = cal_curve_pre.groupby('bucket', as_index=False).agg({'probas' : 'mean', 'true' : 'mean'})
cal_curve['metric'] = abs(cal_curve['true'] - cal_curve['probas']) / cal_curve['true']

# %%
cal_curve
# Out:
#     bucket    probas      true    metric
# 0        0  0.041628  0.049833  0.164651
# 1        1  0.066559  0.078333  0.150314
# 2        2  0.089606  0.105333  0.149309
# 3        3  0.113258  0.115500  0.019414
# 4        4  0.138215  0.156167  0.114950
# 5        5  0.165231  0.175000  0.055823
# 6        6  0.194580  0.204833  0.050057
# 7        7  0.229140  0.243167  0.057685
# 8        8  0.277261  0.269667  0.028163
# 9        9  0.369629  0.350667  0.054074
# 10      10  0.518608  0.516517  0.004049

# %%
plt.plot([0, 1], [0, 1], color='green', linestyle='--')
plt.plot(cal_curve['probas'], cal_curve['true'], color='red')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0]);

# %%
cal_curve
# Out:
#     bucket    probas      true    metric
# 0        0  0.041628  0.049833  0.164651
# 1        1  0.066559  0.078333  0.150314
# 2        2  0.089606  0.105333  0.149309
# 3        3  0.113258  0.115500  0.019414
# 4        4  0.138215  0.156167  0.114950
# 5        5  0.165231  0.175000  0.055823
# 6        6  0.194580  0.204833  0.050057
# 7        7  0.229140  0.243167  0.057685
# 8        8  0.277261  0.269667  0.028163
# 9        9  0.369629  0.350667  0.054074
# 10      10  0.518608  0.516517  0.004049

# %%
print(f'Доля точек с метрикой >20%: {cal_curve[cal_curve["metric"] > 0.2].shape[0] / cal_curve.shape[0]}')
# Out:
# Доля точек с метрикой >20%: 0.0

# %% [markdown]
# ## Тест M5.1: Сравнение эффективности ранжирования модели на разработке и валидации

# %%
print(f'Абсолютное изменение коэффициента Джини при валидации по сравнению с этапом разработки модели: {(2 * roc_auc_score(y_val, lr.predict_proba(X_val)[:, 1]) - 1) - (2 * roc_auc_score(y_train, lr.predict_proba(X_train)[:, 1]) - 1)}')
# Out:
# Абсолютное изменение коэффициента Джини при валидации по сравнению с этапом разработки модели: -0.01964481272098273

# %%
print(f'Относительное изменение коэффициента Джини при валидации по сравнению с этапом разработки модели: {((2 * roc_auc_score(y_val, lr.predict_proba(X_val)[:, 1]) - 1) - (2 * roc_auc_score(y_train, lr.predict_proba(X_train)[:, 1]) - 1)) / (2 * roc_auc_score(y_train, lr.predict_proba(X_train)[:, 1]) - 1)}')
# Out:
# Относительное изменение коэффициента Джини при валидации по сравнению с этапом разработки модели: -0.051934300310841584

# %%
ginis_comparison = {'Train': 2 * roc_auc_score(y_train, lr.predict_proba(X_train)[:, 1]) - 1, 'Validation': 2 * roc_auc_score(y_val, lr.predict_proba(X_val)[:, 1]) - 1}
pd.Series(ginis_comparison).plot(kind='bar');

# %% [markdown]
# ## Тест M5.2: Сравнение эффективности ранжирования отдельных факторов модели на разработке и валидации

# %%
def feature_flg(x):
    if x['abs_change'] < -0.05 and x['rel_change'] < -0.2:
        return 'red'
    elif x['abs_change'] < -0.03 and x['rel_change'] < -0.15:
        return 'yellow'
    else:
        return 'green'

# %%
gini_for_features_train = {}
gini_for_features_val = {}
for column in X_val.columns:
    X_zeros = pd.DataFrame(np.zeros(X_train.shape), columns=X_train.columns)
    X_zeros[column] = X_train[column]
    gini_for_features_train[column] = 2 * roc_auc_score(y_train, lr.predict_proba(X_zeros)[:, 1]) - 1
    X_zeros = pd.DataFrame(np.zeros(X_val.shape), columns=X_val.columns)
    X_zeros[column] = X_val[column]
    gini_for_features_val[column] = 2 * roc_auc_score(y_val, lr.predict_proba(X_zeros)[:, 1]) - 1

# %%
gini_features_comp = pd.DataFrame()
gini_features_comp['gini_train'] = gini_for_features_train
gini_features_comp['gini_val'] = gini_for_features_val
gini_features_comp['abs_change'] = gini_features_comp['gini_val'] - gini_features_comp['gini_train']
gini_features_comp['rel_change'] = (gini_features_comp['gini_val'] - gini_features_comp['gini_train']) / gini_features_comp['gini_train']
gini_features_comp['feature_flg'] = gini_features_comp.apply(lambda x: feature_flg(x), axis=1)

# %%
plt.bar(gini_features_comp.index, gini_features_comp['gini_train'], width=-0.4, align='edge', label='Train', color='green')
plt.bar(gini_features_comp.index, gini_features_comp['gini_val'], width=0.4, align='edge', label='Validation', color='limegreen')
plt.xticks(rotation=90)
plt.ylabel('Gini')
plt.legend();

# %%
gini_features_comp
# Out:
#                       gini_train  gini_val  abs_change  rel_change feature_flg
# purpose                 0.078703  0.061069   -0.017634   -0.224061       green
# sub_grade               0.314731  0.332032    0.017300    0.054968       green
# emp_title               0.053139  0.087293    0.034154    0.642733       green
# dti                     0.109655  0.147593    0.037938    0.345981       green
# funded_amnt             0.078564  0.038379   -0.040185   -0.511492      yellow
# annual_inc              0.090019  0.093239    0.003220    0.035772       green
# term                    0.184200  0.125002   -0.059197   -0.321377         red
# inq_last_6mths          0.092526  0.090339   -0.002187   -0.023638       green
# acc_open_past_24mths    0.092746  0.146763    0.054017    0.582416       green
# avg_cur_bal             0.066240  0.096341    0.030101    0.454420       green
